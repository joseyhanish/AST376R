# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('co2_mm_mlo.txt')
year = data[:,2]
co2 = data[:,3]
plt.plot(year,co2)
plt.xlim(1958., 2018.)
plt.ylim(300.,430.)
plt.show()
